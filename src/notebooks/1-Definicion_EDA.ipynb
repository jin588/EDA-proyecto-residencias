# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### RESIDENCIAS DE MAYORES

# %%
#Escribe el título del proyecto en Markdown
titulo = "Residencias de Mayores"

# %% [markdown]
# ### TEMA

# %%
# PRUEBA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = "La OMS recomienda una tasa de cobertura en residencias de mayores de un 5% por cada mayor de 64 años, se cumple esa ratio en España? y en Madrid?"

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = "Hay suficientes residencias de mayores en España? y en Madrid?"

# %%
# Escribe más hipótesis si las hubiera en Markdown
# hipotesis_2 = "En que provincia tendria mas sentido construir una residencia"
# hipotesis_3 = "En que municipio de Madrid tendria más sentido"
# hipotesis_4 = "Aumentara la demanda en los proximos años?"
# hipotesis_5 = "Podrá el estado seguir proporcionando plaza publicas y ayudas economicas según la demanda ( en el caso de que la hipotesis 4 sea verdadera, que lo es)"
# la 5 creo que solo la voy a dejar planteada para cuando sepa más...

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
# guarda en variables los datasets y su fuente
poblacion_65_mas = pd.read_csv("poblacion +65 por comunidades.csv", sep="\t", encoding = "latin-1",)
fuente_1 = "INE"
pob_Madrid_65_mas = pd.read_csv("poblacion_municipios_mayores65_madrid.csv", sep="\t",encoding= "latin-1")
fuente_2 = "INE"
resdiencias_madrid = pd.read_csv("residencias_madrid_municipios.csv", delimiter = ";", encoding= "latin-1")
fuente_3 = "INE"
residencias_españa = pd.read_csv("residencias_por_provincias_comunidades_2020.csv", sep=";", encoding = "UTF-8" )
fuente_4 = "envejecimiento.csic.es"
# df_5 = pd.DataFrame()
# fuente_5 = ""
# ...

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# dataset poblacion >64 años por comunidades
poblacion_65_mas.head(10)
# Out:
#   Comunidades y Ciudades Autónomas    Total                Edad Fecha
# 0                           España  9479010  65 -100 años y mas  2022
# 1                     01 Andalucía  1526988  65 -100 años y mas  2022
# 2                        02 Aragón   292934  65 -100 años y mas  2022
# 3       03 Asturias, Principado de   272856  65 -100 años y mas  2022
# 4                04 Balears, Illes   192285  65 -100 años y mas  2022
# 5                      05 Canarias   372867  65 -100 años y mas  2022
# 6                     06 Cantabria   135065  65 -100 años y mas  2022
# 7               07 Castilla y León   622101  65 -100 años y mas  2022
# 8          08 Castilla - La Mancha   395507  65 -100 años y mas  2022
# 9                      09 Cataluña  1501795  65 -100 años y mas  2022

# %%
poblacion_65_mas.shape
# Out:
# (160, 7)

# %%
# dataset poblacion >64 por municipios
pob_Madrid_65_mas.head(10)
# Out:
#     Sexo Provincias         Municipios Edad (grupos quinquenales)  \
# 0  Total  28 Madrid                NaN            De 65 a 69 años
# 1  Total  28 Madrid                NaN          De 70 a 74 años
# 2  Total  28 Madrid                NaN          De 75 a 79 años
# 3  Total  28 Madrid                NaN          De 80 a 84 años
# 4  Total  28 Madrid                NaN          De 85 a 89 años
# 5  Total  28 Madrid                NaN          De 90 a 94 años
# 6  Total  28 Madrid                NaN          De 95 a 99 años
# 7  Total  28 Madrid                NaN             100 y más años
# 8  Total  28 Madrid  28001 Acebeda, La            De 65 a 69 años
# 9  Total  28 Madrid  28001 Acebeda, La          De 70 a 74 años
#
#               Periodo    Total
# 0  1 de enero de 2022  329.303
# 1  1 de enero de 2022  294.514
# 2  1 de enero de 2022  242.218
# 3  1 de enero de 2022  163.620
# 4  1 de enero de 2022  126.636
# 5  1 de enero de 2022   60.952
# ...

# %%
pob_Madrid_65_mas.shape
# Out:
# (1440, 6)

# %%
# dataset residencias por comunidades
resdiencias_madrid.head(20)
# Out:
#                                          Denominación        Vía  \
# 0                 Residencia de ancianos Los Jazmines     Camino
# 1              Residencia de 3ª edad San Juan de Dios  Carretera
# 2                      Residencia de la 3ª edad Benja    Avenida
# 3                       Residencia Santa Gema Galgani      Calle
# 4                           Residencia La Edad de Oro    Avenida
# 5          Residencia de mayores Hospital de Antezana      Calle
# 6                         Residencia Cervantes I y II      Calle
# 7   Residencia de personas mayores Francisco de Vi...      Calle
# 8             Residencia de personas mayores Cisneros    Avenida
# 9                                  DomusVi Espartales      Calle
# 10                          DomusVi Alcalá de Henares    Avenida
# 11                        Sanitas Residencial Henares      Calle
# 12                         Ballesol Alcalá de Henares      Calle
# ...

# %%
resdiencias_madrid.shape
# Out:
# (563, 13)

# %%
# dataset residencias por municipios
residencias_españa.head(10)
# Out:
#   Unnamed: 0          Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0        NaN                 NaN        NaN        NaN
# 1        NaN  Total centros 2020        NaN        NaN
# 2        NaN            Absoluto  Centros 1    N. S. 2
# 3      TOTAL               5.567      5.556         11
# 4  Andalucía                 668        667          1
# 5    Almería                  43         43          0
# 6      Cádiz                  68         68          0
# 7    Córdoba                  87         87          0
# 8    Granada                  74         74          0
# 9     Huelva                  37         37          0
#
#                                Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                                     NaN        NaN        NaN        NaN
# 1  Distribución de centros 1 según tamaño        NaN        NaN        NaN
# 2                                    < 25    25 - 49      50-99     >= 100
# ...

# %%
residencias_españa.shape
# Out:
# (71, 9)

# %%
poblacion_65_mas.head()
# Out:
#   Comunidades y Ciudades Autónomas Edad (grupos quinquenales)   Año      Total
# 0                           España                 65-69 años  2022  2.548.001
# 1                           España                 70-74 años  2022  2.225.627
# 2                           España                 75-79 años  2022  1.840.899
# 3                           España                 80-84 años  2022  1.256.786
# 4                           España                 85-89 años  2022  1.004.545

# %%
poblacion_65_mas = poblacion_65_mas.drop(columns=["Total Nacional", "Españoles/Extranjeros", "Sexo"])

# %%
poblacion_65_mas["Comunidades y Ciudades Autónomas"] = poblacion_65_mas["Comunidades y Ciudades Autónomas"].fillna("España")

# %%
poblacion_65_mas.head(10)
# Out:
#   Comunidades y Ciudades Autónomas Edad (grupos quinquenales)   Año      Total
# 0                           España                 65-69 años  2022  2.548.001
# 1                           España                 70-74 años  2022  2.225.627
# 2                           España                 75-79 años  2022  1.840.899
# 3                           España                 80-84 años  2022  1.256.786
# 4                           España                 85-89 años  2022  1.004.545
# 5                           España                 90-94 años  2022    464.255
# 6                           España                 95-99 años  2022    119.258
# 7                           España             100 años y más  2022     19.639
# 8                     01 Andalucía                 65-69 años  2022    438.137
# 9                     01 Andalucía                 70-74 años  2022    367.290

# %%
poblacion_65_mas['Total'] = poblacion_65_mas['Total'].apply(lambda x: int(x.replace('.', '')))
poblacion_65_mas['Año'] = poblacion_65_mas['Año'].astype(str)
poblacion_65_mas = poblacion_65_mas.groupby(poblacion_65_mas.index // 8).agg({'Comunidades y Ciudades Autónomas': 'first',
                                     'Edad (grupos quinquenales)': lambda x: ', '.join(x),
                                     'Año': lambda x: ', '.join(x),
                                     'Total': 'sum'})

# %%
poblacion_65_mas['Edad'] = poblacion_65_mas['Edad (grupos quinquenales)'].apply(lambda x: "65 -100 años y mas")
poblacion_65_mas.drop(columns=['Edad (grupos quinquenales)'], inplace=True)

# %%
poblacion_65_mas.head(10)
# Out:
#   Comunidades y Ciudades Autónomas    Total                Edad Fecha
# 0                           España  9479010  65 -100 años y mas  2022
# 1                     01 Andalucía  1526988  65 -100 años y mas  2022
# 2                        02 Aragón   292934  65 -100 años y mas  2022
# 3       03 Asturias, Principado de   272856  65 -100 años y mas  2022
# 4                04 Balears, Illes   192285  65 -100 años y mas  2022
# 5                      05 Canarias   372867  65 -100 años y mas  2022
# 6                     06 Cantabria   135065  65 -100 años y mas  2022
# 7               07 Castilla y León   622101  65 -100 años y mas  2022
# 8          08 Castilla - La Mancha   395507  65 -100 años y mas  2022
# 9                      09 Cataluña  1501795  65 -100 años y mas  2022

# %%
poblacion_65_mas['Fecha'] = poblacion_65_mas['Año'].apply(lambda x: "2022")
poblacion_65_mas.drop(columns=['Año'], inplace=True)

# %%
residencias_españa.head()
# Out:
#   Unnamed: 0          Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0        NaN                 NaN        NaN        NaN
# 1        NaN  Total centros 2020        NaN        NaN
# 2        NaN            Absoluto  Centros 1    N. S. 2
# 3      TOTAL               5.567      5.556         11
# 4  Andalucía                 668        667          1
#
#                                Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0                                     NaN        NaN        NaN        NaN
# 1  Distribución de centros 1 según tamaño        NaN        NaN        NaN
# 2                                    < 25    25 - 49      50-99     >= 100
# 3                                   1.221      1.515      1.564      1.256
# 4                                     119        234        166        148
#
#   Unnamed: 8
# 0        NaN
# 1        NaN
# 2      TOTAL
# 3      5.556
# 4        667

# %%
# ya ejecutado
residencias_españa = residencias_españa.iloc[2:,:2]

# %%
residencias_españa.head(20)
# Out:
#                   Unnamed: 0 Unnamed: 1
# 2                        NaN   Absoluto
# 3                      TOTAL      5.567
# 4                  Andalucía        668
# 5                    Almería         43
# 6                      Cádiz         68
# 7                    Córdoba         87
# 8                    Granada         74
# 9                     Huelva         37
# 10                      Jaén         72
# 11                    Málaga        127
# 12                   Sevilla        160
# 13                    Aragón        275
# 14                    Huesca         55
# 15                    Teruel         35
# 16                  Zaragoza        185
# 17  Asturias (Principado de)        238
# 18           Balears (Illes)         57
# 19                  Canarias         95
# 20              Palmas (Las)         34
# 21    Santa Cruz de Tenerife         61

# %%
residencias_españa.columns = ["Comunidades y Ciudades Autónomas" , "nº de residencias"]

# %%
residencias_españa.loc[3,"Comunidades y Ciudades Autónomas"] = "España"
residencias_españa.head()
# Out:
#   Comunidades y Ciudades Autónomas nº de residencias
# 2                              NaN          Absoluto
# 3                           España             5.567
# 4                        Andalucía               668
# 5                          Almería                43
# 6                            Cádiz                68

# %%
poblacion_65_mas.head(10)
# Out:
#   Comunidades y Ciudades Autónomas    Total                Edad Fecha
# 0                           España  9479010  65 -100 años y mas  2022
# 1                        Andalucía  1526988  65 -100 años y mas  2022
# 2                           Aragón   292934  65 -100 años y mas  2022
# 3          Asturias, Principado de   272856  65 -100 años y mas  2022
# 4                   Balears, Illes   192285  65 -100 años y mas  2022
# 5                         Canarias   372867  65 -100 años y mas  2022
# 6                        Cantabria   135065  65 -100 años y mas  2022
# 7                  Castilla y León   622101  65 -100 años y mas  2022
# 8             Castilla - La Mancha   395507  65 -100 años y mas  2022
# 9                         Cataluña  1501795  65 -100 años y mas  2022

# %%
residencias_españa.head(60)
# Out:
#    Comunidades y Ciudades Autónomas nº de residencias
# 2                               NaN          Absoluto
# 3                            España             5.567
# 4                         Andalucía               668
# 5                           Almería                43
# 6                             Cádiz                68
# 7                           Córdoba                87
# 8                           Granada                74
# 9                            Huelva                37
# 10                             Jaén                72
# 11                           Málaga               127
# 12                          Sevilla               160
# 13                           Aragón               275
# 14                           Huesca                55
# 15                           Teruel                35
# 16                         Zaragoza               185
# 17         Asturias (Principado de)               238
# ...

# %%
poblacion_65_mas['Comunidades y Ciudades Autónomas'] = poblacion_65_mas['Comunidades y Ciudades Autónomas'].replace('\d+', '', regex=True)

# %%
poblacion_65_por_residencia = pd.merge(poblacion_65_mas, residencias_españa, on="Comunidades y Ciudades Autónomas")

# %%
poblacion_65_por_residencia.head()
# Out:
#   Comunidades y Ciudades Autónomas    Total                Edad Fecha  \
# 0                           España  9479010  65 -100 años y mas  2022
#
#   nº de residencias
# 0             5.567

# %%
df_prueba = pd.concat([poblacion_65_mas, residencias_españa], axis = 1)

# %%
df_prueba.head(60)
# Out:
#    Comunidades y Ciudades Autónomas      Total                Edad Fecha  \
# 0                            España  9479010.0  65 -100 años y mas  2022
# 1                         Andalucía  1526988.0  65 -100 años y mas  2022
# 2                            Aragón   292934.0  65 -100 años y mas  2022
# 3           Asturias, Principado de   272856.0  65 -100 años y mas  2022
# 4                    Balears, Illes   192285.0  65 -100 años y mas  2022
# 5                          Canarias   372867.0  65 -100 años y mas  2022
# 6                         Cantabria   135065.0  65 -100 años y mas  2022
# 7                   Castilla y León   622101.0  65 -100 años y mas  2022
# 8              Castilla - La Mancha   395507.0  65 -100 años y mas  2022
# 9                          Cataluña  1501795.0  65 -100 años y mas  2022
# 10             Comunitat Valenciana  1018221.0  65 -100 años y mas  2022
# 11                      Extremadura   226723.0  65 -100 años y mas  2022
# ...
